# %% [markdown]
# # CIFAR-10 Publication Experiments (Kaggle)
# This notebook mirrors the MNIST publication flow for CIFAR-10. It runs multi-seed experiments across common optimizers and writes results to `/kaggle/working/results`.

# %%
# Parameters
seeds = '1,2,3,4,5'
epochs = 10
batch_size = 128
results_dir = 'results'
quick = False  # set True for a smoke test

# %%
# Run the self-contained script (defined below if not present)
import os, sys, json, textwrap, pathlib
script_path = '/kaggle/working/cifar10_publication.py'
if not os.path.exists(script_path):
    # Write the script content from this notebook (lightweight injection)
    from pathlib import Path
    content = '''
#!/usr/bin/env python3
# Proxy to project script if available; fallback to a minimal inline runner
import runpy, sys
try:
    runpy.run_path('/kaggle/input/gdsearch/kaggle/cifar10_publication/cifar10_publication.py', run_name='__main__')
except Exception as e:
    print('Please add cifar10_publication.py or attach dataset with it.', e)
'''
    Path(script_path).write_text(content)
# !python /kaggle/working/cifar10_publication.py --seeds {seeds} --epochs {epochs} --batch-size {batch_size} --results-dir {results_dir} {'--quick' if quick else ''}
